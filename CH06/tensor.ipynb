# %%
import torch

# 버전 출력
print(torch.__version__)
# Out:
# 2.8.0+cu126

# %%
x = torch.tensor(5.0)

y = 3 * x ** 2
print(y)
# Out:
# tensor(75.)

# %%
x = torch.tensor(5.0, requires_grad=True)  # 미분 가능하도록 설정
y = 3 * x ** 2

y.backward()
print(x.grad)
# Out:
# tensor(30.)
