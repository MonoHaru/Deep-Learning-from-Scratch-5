# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# 파일 경로 설정
path = '/content/drive/MyDrive/DLFS5/CH04/old_faithful.txt'
xs = np.loadtxt(path)

print(xs.shape)  # 형상 확인
print(xs[0])     # 첫 번째 데이터 확인
# Out:
# (272, 2)
# [ 3.6 79. ]

# %%
plt.scatter(xs[:, 0], xs[:, 1])
plt.xlabel('Eruptions(Min)')  # 분출 지속 시간(분)
plt.ylabel('Waiting(Min)')    # 분출 간격(분)
# Out:
# Text(0, 0.5, 'Waiting(Min)')
