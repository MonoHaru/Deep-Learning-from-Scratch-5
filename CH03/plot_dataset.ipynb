# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
path = '/content/drive/MyDrive/DLFS5/CH03/height_weight.txt'
xs = np.loadtxt(path)

print(xs.shape)
# Out:
# (25000, 2)

# %%
small_xs = xs[:500]
print(small_xs.shape)
# Out:
# (500, 2)

# %%
plt.scatter(small_xs[:, 0], small_xs[:, 1])
plt.xlabel('Height(cm)')
plt.ylabel('Weight(kg)')
plt.show()
